# %%
import collections
import ROOT
from ROOT import gSystem,TTree,TFile,TCanvas
# Out:
# Welcome to JupyROOT 6.14/04

# %%
import random

# %%
for i in range(1,4):
    print(i)
# Out:
# 1
# 2
# 3

# %%
inFileList = ["/data/atlas/atlasdata/DiHiggsPheno/ntuples/150719/nn_score_ntuples/loose_noGenFilt_4b_highstats_signal_hh_TopYuk_1.0_SlfCoup_5.0_merged.ro.resolved_2_withNNs.root"]

# %%
var =  "event.h1_M"
f = TFile("/data/atlas/atlasdata/DiHiggsPheno/ntuples/150719/nn_score_ntuples/loose_noGenFilt_4b_highstats_signal_hh_TopYuk_1.0_SlfCoup_5.0_merged.ro.resolved_2_withNNs.root")
t = f.Get("preselection")

# %%
t.Print()
# Out:
# ******************************************************************************
# *Tree    :preselection: preselection                                           *
# *Entries :    15853 : Total =        10387307 bytes  File  Size =    7430810 *
# *        :          : Tree compression factor =   1.39                       *
# ******************************************************************************
# *Br    0 :n_small_jets : n_small_jets/I                                      *
# *Entries :    15853 : Total  Size=      64012 bytes  File Size  =       6833 *
# *Baskets :        1 : Basket Size=      64512 bytes  Compression=   9.29     *
# *............................................................................*
# *Br    1 :n_small_tag : n_small_tag/I                                        *
# *Entries :    15853 : Total  Size=      64007 bytes  File Size  =       9707 *
# *Baskets :        1 : Basket Size=      64512 bytes  Compression=   6.54     *
# ...

# %%
c = TCanvas()

# %%
t.Draw("event.h1_M:nnscore_SlfCoup_5.0_sig>>h(40,0,1,40,30,230)","","colz")
c.Draw()

# %%
c.Clear()
# ALL tagged
cutString = 'h2_j1_BTag ==1   && \
             h2_j2_BTag ==1   && \
             h1_j1_BTag ==1   && \
             h1_j2_BTag ==1'
t.Draw("event.h1_M:nnscore_SlfCoup_5.0_sig>>h(40,0,1,40,30,230)",cutString,"colz")
c.Draw()

# %%
c.Clear()
# NONE tagged
cutString = 'h2_j1_BTag ==0   && \
             h2_j2_BTag ==0   && \
             h1_j1_BTag ==0   && \
             h1_j2_BTag ==0'
t.Draw("event.h1_M:nnscore_SlfCoup_5.0_sig>>h(40,0,1,40,30,230)",cutString,"colz")
c.Draw()

# %% [markdown]
# # 3b region

# %%
c.Clear()
# ALL tagged
cutString = 'h2_j1_BTag ==1   && \
             h2_j2_BTag ==1   && \
             h1_j1_BTag ==0   && \
             h1_j2_BTag ==1'
t.Draw("event.h1_M:nnscore_SlfCoup_5.0_sig>>h(40,0,1,40,30,230)",cutString,"colz")
c.Draw()

# %%
c.Clear()
# ALL tagged
cutString = 'h2_j1_BTag ==1   && \
             h2_j2_BTag ==1   && \
             h1_j1_BTag ==1   && \
             h1_j2_BTag ==0'
t.Draw("event.h1_M:nnscore_SlfCoup_5.0_sig>>h(40,0,1,40,30,230)",cutString,"colz")
c.Draw()

# %%
c.Clear()
# ALL tagged
cutString = 'h2_j1_BTag ==1   && \
             h2_j2_BTag ==0   && \
             h1_j1_BTag ==1   && \
             h1_j2_BTag ==1'
t.Draw("event.h1_M:nnscore_SlfCoup_5.0_sig>>h(40,0,1,40,30,230)",cutString,"colz")
c.Draw()

# %%
c.Clear()
# ALL tagged
cutString = 'h2_j1_BTag ==0   && \
             h2_j2_BTag ==1   && \
             h1_j1_BTag ==1   && \
             h1_j2_BTag ==1'
t.Draw("event.h1_M:nnscore_SlfCoup_5.0_sig>>h(40,0,1,40,30,230)",cutString,"colz")
c.Draw()

# %% [markdown]
# # 2b region

# %%
c.Clear()
# Subleading double tagged
cutString = 'h2_j1_BTag ==1   && \
             h2_j2_BTag ==1   && \
             h1_j1_BTag ==0   && \
             h1_j2_BTag ==0'
t.Draw("event.h1_M:nnscore_SlfCoup_5.0_sig>>h(40,0,1,40,30,230)",cutString,"colz")
c.Draw()

# %%
c.Clear()
# Leading double tagged
cutString = 'h2_j1_BTag ==0   && \
             h2_j2_BTag ==0   && \
             h1_j1_BTag ==1   && \
             h1_j2_BTag ==1'
t.Draw("event.h1_M:nnscore_SlfCoup_5.0_sig>>h(40,0,1,40,30,230)",cutString,"colz")
c.Draw()

# %%
c.Clear()
# ALL tagged
cutString = 'h2_j1_BTag ==1   && \
             h2_j2_BTag ==0   && \
             h1_j1_BTag ==0   && \
             h1_j2_BTag ==1'
t.Draw("event.h1_M:nnscore_SlfCoup_5.0_sig>>h(40,0,1,40,30,230)",cutString,"colz")
c.Draw()

# %%
c.Clear()
# ALL tagged
cutString = 'h2_j1_BTag ==0   && \
             h2_j2_BTag ==1   && \
             h1_j1_BTag ==1   && \
             h1_j2_BTag ==0'
t.Draw("event.h1_M:nnscore_SlfCoup_5.0_sig>>h(40,0,1,40,30,230)",cutString,"colz")
c.Draw()

# %% [markdown]
# # 1b region

# %%
c.Clear()
# Leading single tagged
cutString = 'h2_j1_BTag ==0   && \
             h2_j2_BTag ==0   && \
             h1_j1_BTag ==1   && \
             h1_j2_BTag ==0'
t.Draw("event.h1_M:nnscore_SlfCoup_5.0_sig>>h(40,0,1,40,30,230)",cutString,"colz")
c.Draw()

# %%
c.Clear()
# Leading single tagged
cutString = 'h2_j1_BTag ==0   && \
             h2_j2_BTag ==0   && \
             h1_j1_BTag ==0   && \
             h1_j2_BTag ==1'
t.Draw("event.h1_M:nnscore_SlfCoup_5.0_sig>>h(40,0,1,40,30,230)",cutString,"colz")
c.Draw()

# %%
c.Clear()
# Subleading single tagged
cutString = 'h2_j1_BTag ==1   && \
             h2_j2_BTag ==0   && \
             h1_j1_BTag ==0   && \
             h1_j2_BTag ==0'
t.Draw("event.h1_M:nnscore_SlfCoup_5.0_sig>>h(40,0,1,40,30,230)",cutString,"colz")
c.Draw()

# %%
c.Clear()
# Subleading single tagged
cutString = 'h2_j1_BTag ==0   && \
             h2_j2_BTag ==1   && \
             h1_j1_BTag ==0   && \
             h1_j2_BTag ==0'
t.Draw("event.h1_M:nnscore_SlfCoup_5.0_sig>>h(40,0,1,40,30,230)",cutString,"colz")
c.Draw()

# %%
t.Draw("event.h2_M:nnscore_EP15_LR0p005_top","event.h2_M < 300","colz")
c.Draw()
# Out:
# Error in <TTreeFormula::Compile>:  Bad numerical expression : "nnscore_EP15_LR0p005_top"
# Info in <TSelectorDraw::AbortProcess>: Variable compilation failed: {event.h2_M:nnscore_EP15_LR0p005_top,event.h2_M < 300}

# %%
t.Draw("event.h2_M:nnscore_EP15_LR0p005_top","event.h2_M < 300 && nElec  == 0 && nMuon == 0","colz")
c.Draw()

# %%
t.Draw("nElec:nnscore_EP15_LR0p005_top","","colz")
c.Draw()

# %%
c = TCanvas()
t.Draw("nMuon:nnscore_EP15_LR0p005_top","","colz")
c.Draw()

# %%
c = TCanvas()
t.Draw("event.muon1_Pt:nnscore_EP15_LR0p005_top","","colz")
c.Draw()

# %%
c = TCanvas()
t.Draw("event.elec1_Pt:nnscore_EP15_LR0p005_top","","colz")
c.Draw()

# %%
t.Draw("event.met_Phi:nnscore_EP15_LR0p005_top","","colz")
c.Draw()

# %%
t.Draw("event.elec1_Eta:nnscore_EP15_LR0p005_top","","colz")
c.Draw()

# %%
t.Draw("event.muon1_Eta:nnscore_EP15_LR0p005_top","","colz")
c.Draw()

# %%
t.Draw("event.elec1_Phi:nnscore_EP15_LR0p005_top","","colz")
c.Draw()

# %%
t.Draw("event.muon1_Phi:nnscore_EP15_LR0p005_top","","colz")
c.Draw()

# %%
t.Draw("event.met_Et:nnscore_EP15_LR0p005_top","event.met_Et <300","colz")
c.Draw()

# %%
t.Draw("event.elec1_Eta")
c.Draw()

# %%
# %load plot_score_vs_mass.py
import collections
from ROOT import gSystem,TTree,TFile,TCanvas
import ROOT


def main():
  inFileList = [
    "intermediate_ptj1_1000_to_infty_bkg_2b2j_withNNs.root.boosted_2_withNNs.root",
    "intermediate_ptj1_200_to_500_bkg_2b2j_withNNs.root.boosted_2_withNNs.root",
    "intermediate_ptj1_20_to_200_bkg_2b2j_withNNs.root.boosted_2_withNNs.root",
    "intermediate_ptj1_500_to_1000_bkg_2b2j_withNNs.root.boosted_2_withNNs.root",
    "intermediate_ptj1_1000_to_infty_bkg_4b_withNNs.root.boosted_2_withNNs.root",
    "intermediate_ptj1_200_to_500_bkg_4b_withNNs.root.boosted_2_withNNs.root",
    "intermediate_ptj1_20_to_200_bkg_4b_withNNs.root.boosted_2_withNNs.root",
    "intermediate_ptj1_500_to_1000_bkg_4b_withNNs.root.boosted_2_withNNs.root",
    "OxHHPh_06May2019_MG5_262_Py8_14TeV_NNPDF30NLO_Dlph3_pp2hh_4b_HeavyHiggsTHDM_TopYuk_1.0_SlfCoup_1.0_merged_ntup_withNNs.root.boosted_2_withNNs.root",
    "intermediate_noGenFilt_bkg_ttbar_trackJetBTag_withNNs.root.boosted_2_withNNs.root",
    "intermediate_ptj1_1000_to_infty_bkg_2b2j_withNNs.root.intermediate_2_withNNs.root",
    "intermediate_ptj1_200_to_500_bkg_2b2j_withNNs.root.intermediate_2_withNNs.root",
    "intermediate_ptj1_20_to_200_bkg_2b2j_withNNs.root.intermediate_2_withNNs.root",
    "intermediate_ptj1_500_to_1000_bkg_2b2j_withNNs.root.intermediate_2_withNNs.root",
    "intermediate_ptj1_1000_to_infty_bkg_4b_withNNs.root.intermediate_2_withNNs.root",
    "intermediate_ptj1_200_to_500_bkg_4b_withNNs.root.intermediate_2_withNNs.root",
    "intermediate_ptj1_20_to_200_bkg_4b_withNNs.root.intermediate_2_withNNs.root",
    "intermediate_ptj1_500_to_1000_bkg_4b_withNNs.root.intermediate_2_withNNs.root",
    "OxHHPh_06May2019_MG5_262_Py8_14TeV_NNPDF30NLO_Dlph3_pp2hh_4b_HeavyHiggsTHDM_TopYuk_1.0_SlfCoup_1.0_merged_ntup_withNNs.root.intermediate_2_withNNs.root",
    "intermediate_noGenFilt_bkg_ttbar_trackJetBTag_withNNs.root.intermediate_2_withNNs.root",
    "intermediate_ptj1_200_to_500_bkg_2b2j_withNNs.root.resolved_2_withNNs.root",
    "intermediate_ptj1_20_to_200_bkg_2b2j_withNNs.root.resolved_2_withNNs.root",
    "intermediate_ptj1_500_to_1000_bkg_2b2j_withNNs.root.resolved_2_withNNs.root",
    "intermediate_ptj1_200_to_500_bkg_4b_withNNs.root.resolved_2_withNNs.root",
    "intermediate_ptj1_20_to_200_bkg_4b_withNNs.root.resolved_2_withNNs.root",
    "intermediate_ptj1_500_to_1000_bkg_4b_withNNs.root.resolved_2_withNNs.root",
    "OxHHPh_06May2019_MG5_262_Py8_14TeV_NNPDF30NLO_Dlph3_pp2hh_4b_HeavyHiggsTHDM_TopYuk_1.0_SlfCoup_1.0_merged_ntup_withNNs.root.resolved_2_withNNs.root",
    "intermediate_noGenFilt_bkg_ttbar_trackJetBTag_withNNs.root.resolved_2_withNNs.root"
    ]

  #inFileList = ["interm_2b2j_500_to_1000.root",
  #              "boosted_2b2j_500_to_1000.root",
  #              "resolved_2b2j_500_to_1000.root",
  #              "boosted_2b2j_1000_to_infty.root",
  #              "interm_2b2j_1000_to_infty.root",
  #              "interm_4b_1000_to_infty.root",
  #              "boosted_4b_1000_to_infty.root",
  #              "boosted_4b_20_to_200.root",
  #              "resolved_4b_20_to_200.root",
  #              "interm_4b_20_to_200.root",
  #              "interm_4b_200_to_500.root",
  #              "boosted_4b_200_to_500.root",
  #              "resolved_4b_200_to_500.root",
  #              "resolved_4b_500_to_1000.root",
  #              "interm_4b_500_to_1000.root",
  #              "boosted_4b_500_to_1000.root"]

  #inFileList = ["resolved_2b2j_200_to_500.root",
  #              "interm_2b2j_200_to_500.root",
  #              "boosted_2b2j_200_to_500.root"
  #              ]

  #inFileList = ["resolved_signal.root",
  #              "boosted_signal.root",
  #              "interm_signal.root",
  #              "resolved_ttbar.root",
  #              "boosted_ttbar.root",
  #              "interm_ttbar.root"
  #              ]
  varList = ["event.h1_M","event.h2_M","event.m_hh"]
  #netList = ["nnscore_w_OPsgdEP30BS100DO05","nnscore_w_OPadamaxEP30BS100DO03"]
  netList = ["EP15_LR0p005"]
  for fileName in inFileList:
    f = TFile(fileName)
    t = f.Get("preselection")
    for var in varList:
      for net in netList:
        text = "text"
        if fileName.find("pp2hh_4b_HeavyHiggsTHDM") > 0:
          text = "Signal sample, "
        elif fileName.find("bkg_ttbar") > 0:
          text = "ttbar sample, "
        else:
          text = "QCD bkg sample, "
        if fileName.find(".root.resolved") > 0:
          text = text + "resolved"
        elif fileName.find(".root.boosted") > 0:
          text = text + "boosted"
        elif fileName.find(".root.intermediate") > 0:
          text = text + "intermediate"

        c = TCanvas()
        latex = ROOT.TLatex()
        latex.SetNDC()
        latex.SetTextFont( 42 )
        latex.SetTextSize( 0.035 )
        latex.SetTextColor( 1 )
        latex.SetTextAlign( 12 )

        t.Draw(var+":nnscore_"+net+"_sig","","colz")
        latex.DrawLatex( 0.22, 0.87, ' #bf{%s }' % (text))
        c.Print(fileName+var+"VSnnscore_"+net+"_sig.png")
        t.Draw(var+":nnscore_"+net+"_qcd","","colz")
        latex.DrawLatex( 0.22, 0.87, ' #bf{%s }' % (text))
        c.Print(fileName+var+"VSnnscore_"+net+"_qcd.png")
        t.Draw(var+":nnscore_"+net+"_top","","colz")
        latex.DrawLatex( 0.22, 0.87, ' #bf{%s }' % (text))
        c.Print(fileName+var+"VSnnscore_"+net+"_top.png")
      
  
class MyDict(collections.OrderedDict):
  def __missing__(self, key):
    val = self[key] = MyDict()
    return val

if __name__ == "__main__":
    main()
